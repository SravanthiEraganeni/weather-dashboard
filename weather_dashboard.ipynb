# %%
import requests
import csv
import datetime
import matplotlib.pyplot as plt

API_KEY = '092618f1276fca0b8c87ca389da8314f'
cities = [
    'Hyderabad', 'Delhi', 'Mumbai', 'Chennai', 'Bangalore',
    'Kolkata', 'Pune', 'Ahmedabad', 'Jaipur', 'Lucknow',
    'Visakhapatnam', 'Bhopal', 'Indore', 'Patna', 'Nagpur',
    'Vijayawada', 'Coimbatore', 'Surat', 'Rajkot', 'Noida',
    'London', 'New York', 'Paris', 'Tokyo', 'Dubai',
    'Singapore', 'Bangkok', 'Berlin', 'Toronto', 'San Francisco',
    'Los Angeles', 'Chicago', 'Melbourne', 'Cape Town', 'Doha'
]

today = datetime.date.today()

filename = 'weather_data.csv'

with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Date', 'City', 'Country', 'Temp (°C)', 'Feels Like (°C)', 'Humidity (%)', 'Pressure (hPa)', 'Wind Speed (m/s)', 'Cloudiness (%)', 'Weather']
)

    for city in cities:
        url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric'
        response = requests.get(url)
        data = response.json()

        # Extract all values
        temp = data['main']['temp']
        feels_like = data['main']['feels_like']
        humidity = data['main']['humidity']
        pressure = data['main']['pressure']
        wind_speed = data['wind']['speed']
        clouds = data['clouds']['all']
        weather = data['weather'][0]['description']
        country = data['sys']['country']
        

        # Print full weather summary
        print(f"""
        📍 City: {city}, {country}
        🌡️  Temperature: {temp}°C (Feels Like: {feels_like}°C)
        💧 Humidity: {humidity}%
        🔼 Pressure: {pressure} hPa
        💨 Wind Speed: {wind_speed} m/s
        ☁️  Cloudiness: {clouds}%
        🌤️ Weather: {weather}
        -------------------------------------------
        """)
        writer.writerow([today, city, temp, feels_like, humidity, pressure, wind_speed, clouds, weather, country])
# Out:
#         📍 City: Hyderabad, IN
#         🌡️  Temperature: 27.69°C (Feels Like: 28.81°C)
#         💧 Humidity: 58%
#         🔼 Pressure: 1009 hPa
#         💨 Wind Speed: 6.61 m/s
#         ☁️  Cloudiness: 100%
#         🌤️ Weather: overcast clouds
#         -------------------------------------------
#
#
#         📍 City: Delhi, IN
#         🌡️  Temperature: 31.32°C (Feels Like: 37.23°C)
#         💧 Humidity: 66%
#         🔼 Pressure: 1001 hPa
#         💨 Wind Speed: 3.6 m/s
#         ☁️  Cloudiness: 100%
#         🌤️ Weather: overcast clouds
#         -------------------------------------------
#
#
#         📍 City: Mumbai, IN
#         🌡️  Temperature: 27.73°C (Feels Like: 31.86°C)
#         💧 Humidity: 83%
#         🔼 Pressure: 1006 hPa
#         💨 Wind Speed: 8 m/s
#         ☁️  Cloudiness: 86%
#         🌤️ Weather: moderate rain
#         -------------------------------------------
#
#
#         📍 City: Chennai, IN
#         🌡️  Temperature: 36.65°C (Feels Like: 39.37°C)
# ...

# %%
print(df.columns)
# Out:
# Index(['Date', 'City', 'Country', 'Temp (°C)', 'Feels Like (°C)',
#        'Humidity (%)', 'Pressure (hPa)', 'Wind Speed (m/s)', 'Cloudiness (%)',
#        'Weather'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date

today = date.today()
df = pd.read_csv('weather_data.csv')

# 🌡️ Temperature Comparison
plt.figure(figsize=(25,10))
plt.bar(df['City'], df['Temp (°C)'], color='skyblue')
plt.title(f'Temperature Comparison - {today}')
plt.xlabel('City')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(axis='y')
plt.savefig('temperature_chart.png')
plt.show()
